# %% [markdown]
# <h2 style = color:green>System Prompts</h2>
# <p style = color:yellow>Run the cell which contains the Role you want the Assistant to take.</p>

# %%
# !echo -e "You are a Python coding assistant.\\nThe USER will give you instructions to help write functions.\\nYou may ask for clarification if needed, but otherwise you should only output Python code, if there are comments in the code then keep them.\\nAdhere to PEP8. Provide explanations of the code only if the user asks for them.\\n\\nThe below code scratchpad may be provided by the user so you are aware of the script they are working on.\\nNote, this information may be blank.\\nEven if the below information is populated, it may not be relevant to the user's request.\\nUse your best judgment to discern if the user is asking for you to modify the below code,\\nor if the code is there for reference.\\n\\nCoding scratchpad:\\nTest Orange" > system_message.txt

# %%
# !echo $SHELL

# %%
import json

# Set the title of the cell containing the system message
cell_title = "Python"

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find the cell with the specified title
cell = next(c for c in nb["cells"] if c.get("metadata", {}).get("title") == cell_title)

# Get the contents of the cell and format the shell command
message = "".join(cell["source"])
command = f"echo -e \"{message}\" > system_message.txt"

# Output the formatted shell command in the next cell
print(f"%%shell\n{command}")

# %% [markdown]
# You are a Python coding assistant.
# The USER will give you instructions to help write functions.
# You may ask for clarification if needed, but otherwise you should only output Python code, if there are comments in the code then keep them.
# Adhere to PEP8. Provide explanations of the code only if the user asks for them.
#
# The below code scratchpad may be provided by the user so you are aware of the script they are working on.
# Note, this information may be blank.
# Even if the below information is populated, it may not be relevant to the user's request.
# Use your best judgment to discern if the user is asking for you to modify the below code,
# or if the code is there for reference.
#
# Coding scratchpad:
# Test: Orange
# ```python
# <<CODE>>
# ```

# %%
import json
import re

# Set the search string for the cell containing the system message
search_string = "Python"

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find the cell with the specified search string in the metadata, contents, or outputs
pattern = re.compile(search_string, re.IGNORECASE)
cells = [c for c in nb["cells"] if search_string in "".join(c.get("source", [])).lower()]
            
if len(cells) == 0:
    print(f"No cell found containing the search string '{search_string}'.")
elif len(cells) > 1:
    print(f"Multiple cells found containing the search string '{search_string}'.")
else:
    # Get the contents of the cell and format the shell command
    message = "".join(cells[0]["source"])
    command = f"echo -e \"{message}\" > system_message.txt"

    # Output the formatted shell command in the next cell
    print(f"%%shell\n{command}")

# %%
import json

# Set the search string for the cell containing the system message
search_string = "Python"

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Print the contents and metadata of each cell
for i, cell in enumerate(nb["cells"]):
    print(f"Cell {i}:")
    print(f"Metadata: {cell.get('metadata', {})}")
    print(f"Contents: {cell['source']}")
    print()

# Find the cell with the specified search string in the metadata or contents
cells = [c for c in nb["cells"] if (search_string in c.get("metadata", {}).get("title", "").lower()) 
        or (search_string in "".join(c["source"]).lower())]

if len(cells) == 0:
    print(f"No cell found containing the search string '{search_string}'.")
elif len(cells) > 1:
    print(f"Multiple cells found containing the search string '{search_string}'.")
else:
    # Get the contents of the cell and format the shell command
    message = "".join(cells[0]["source"])
    command = f"echo -e \"{message}\" > system_message.txt"

    # Output the formatted shell command in the next cell
    print(f"%%shell\n{command}")

# %%
import json

# Set the search string for the cell containing the system message
search_string = "Python"

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Print the contents and metadata of each cell
for i, cell in enumerate(nb["cells"]):
    print(f"Cell {i}:")
    print(f"Metadata: {cell.get('metadata', {})}")
    print(f"Contents: {cell['source']}")
    print()

# %% [markdown]
# ```python
# # Get the notebook metadata
# with open("chat.ipynb", "r") as f:
#     nb = json.load(f)
#
# # Find the cell with the specified search string in the metadata, contents, or outputs
# cells = []
# for cell in nb["cells"]:
#     if search_string in cell.get("metadata", {}).get("title", "").lower():
#         cells.append(cell)
#     else:
#         contents = "".join(cell.get("source", []))
#         outputs = "".join([o.get("text", "") for o in cell.get("outputs", [])])
#         if search_string in (contents + outputs).lower():
#             cells.append(cell)
# ```

# %%
import json

# Set the search string for the cell containing the system message
search_string = "Python"

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find the cell with the specified search string in the metadata or contents
cells = [c for c in nb["cells"] if search_string in "".join(c.get("source", [])).lower()]

if len(cells) == 0:
    print(f"No cell found containing the search string '{search_string}'.")
elif len(cells) > 1:
    print(f"Multiple cells found containing the search string '{search_string}'.")
else:
    # Get the contents of the cell and format the shell command
    message = "".join(cells[0]["source"])
    command = f"echo -e \"{message}\" > system_message.txt"

    # Output the formatted shell command in the next cell
    print(f"%%shell\n{command}")

# %% [markdown]
# ```python
# import json
#
# # Set the search string for the cell containing the system message
# search_string = "Python coding assistant"
#
# # Get the notebook metadata
# with open("chat.ipynb", "r") as f:
#     nb = json.load(f)
#
# # Find the cell with the specified search string in the metadata or contents
# cells = [c for c in nb["cells"] if search_string in "".join(c.get("source", [])).lower()]
#
# if len(cells) == 0:
#     print(f"No cell found containing the search string '{search_string}'.")
#     # Print out the contents of each cell for debugging purposes
#     for cell in nb["cells"]:
#         print("".join(cell.get("source", [])))
# elif len(cells) > 1:
#     print(f"Multiple cells found containing the search string '{search_string}'.")
# else:
#     # Get the contents of the cell and format the shell command
#     message = "".join(cells[0]["source"])
#     command = f"echo -e \"{message}\" > system_message.txt"
#
#     # Output the formatted shell command in the next cell
#     print(f"%%shell\n{command}")
# ```

# %%
import json

# Set the search string for the cell containing the system message
search_string = "Python"

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Print out the contents of the "source" key of each cell in the notebook
for cell in nb["cells"]:
    print(cell["source"])

# Find the cell with the specified search string in the metadata or contents
cells = [c for c in nb["cells"] if search_string in "".join(c.get("source", [])).lower()]

if len(cells) == 0:
    print(f"No cell found containing the search string '{search_string}'.")
elif len(cells) > 1:
    print(f"Multiple cells found containing the search string '{search_string}'.")
else:
    # Get the contents of the cell and format the shell command
    message = "".join(cells[0]["source"])
    command = f"echo -e \"{message}\" > system_message.txt"

    # Output the formatted shell command in the next cell
    print(f"%%shell\n{command}")

# %%
# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and print out their source
for cell in nb["cells"]:
    print("".join(cell.get("source", [])).lower())

# Find all the cells in the notebook and count the number of times "Python" appears
count = 0
for cell in nb["cells"]:
    if "Python" in "".join(cell.get("source", [])).lower():
        count += 1

# Print out the number of times "Python" appears in the notebook
print(f"The word 'Python' appears {count} times in the notebook.")

# %%
# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and count the number of times "Python" appears
count = 0
for cell in nb["cells"]:
    for output in cell.get("outputs", []):
        if output.get("output_type", "") == "stream" and "Python" in output.get("text", "").lower():
            count += 1

# Print out the number of times "Python" appears in the notebook
print(f"The word 'Python' appears {count} times in the notebook.")

# %%
# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and count the number of times "Python" appears
count = 0
for cell in nb["cells"]:
    for output in cell.get("outputs", []):
        if output.get("output_type", "") == "stream" and "Python" in "".join(output.get("text", [])).lower():
            count += 1

# Print out the number of times "Python" appears in the notebook
print(f"The word 'Python' appears {count} times in the notebook.")

# %%
# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and count the number of times "print" appears
count = 0
for cell in nb["cells"]:
    for output in cell.get("outputs", []):
        if output.get("output_type", "") == "stream" and "print" in "".join(output.get("text", [])).lower():
            count += 1

# Print out the number of times "print" appears in the notebook
print(f"The word 'print' appears {count} times in the notebook.")

# %%
# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and count the number of times "Python" appears
count = 0
for cell in nb["cells"]:
    if "Python" in cell.get("source", "").lower():
        count += 1
    for output in cell.get("outputs", []):
        if output.get("output_type", "") == "stream" and "Python" in "".join(output.get("text", [])).lower():
            count += 1

# Print out the number of times "Python" appears in the notebook
print(f"The word 'Python' appears {count} times in the notebook.")

# %%
# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and count the number of times "Python" appears
count = 0
for cell in nb["cells"]:
    if "Python" in "".join(cell.get("source", [])).lower():
        count += 1
    for output in cell.get("outputs", []):
        if output.get("output_type", "") == "stream" and "Python" in "".join(output.get("text", [])).lower():
            count += 1

# Print out the number of times "Python" appears in the notebook
print(f"The word 'Python' appears {count} times in the notebook.")

# %%
import json

# Get the notebook metadata
with open("chat.ipynb", "r") as f:
    nb = json.load(f)

# Find all the cells in the notebook and count the number of times "Python" appears
count = 0
for cell in nb["cells"]:
    if "python" in "".join(cell.get("source", [])).lower():
        count += 1
    for output in cell.get("outputs", []):
        if output.get("output_type", "") == "stream" and "python" in "".join(output.get("text", [])).lower():
            count += 1

# Print out the number of times "Python" appears in the notebook
print(f"The word 'Python' appears {count} times in the notebook.")

# %% [markdown]
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_231722_gpt-4_request.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_231731_495_response.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_232912_gpt-4_request.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_232922_651_response.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_233120_gpt-4_request.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_233129_768_response.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_233723_gpt-4_request.md
# Apps/Coding_ChatBot_Assistant/log/openai/20230705_233807_870_response.md

# %% [markdown]
# [Title](log/openai/20230705_231722_gpt-4_request.md) [Title](log/openai/20230705_231731_495_response.md) [Title](log/openai/20230705_232912_gpt-4_request.md) [Title](log/openai/20230705_232922_651_response.md) [Title](log/openai/20230705_233120_gpt-4_request.md) [Title](log/openai/20230705_233129_768_response.md) [Title](log/openai/20230705_233723_gpt-4_request.md) [Title](log/openai/20230705_233807_870_response.md)

# %%
#!/home/bitawatt/anaconda3/envs/Code_Chat-env/bin/python
import argparse
import json
import os
import textwrap
import time
from datetime import datetime
from typing import Any, Union
from typing import List

from pygments import highlight
from pygments.lexers import PythonLexer
from pygments.formatters import TerminalFormatter

import openai

class AppState:
    def __init__(self):
        self.MODEL_NAME = "gpt-4"
        self.MODEL_TEMPERATURE = 0.1
        self.MODEL_MAX_TOKENS = 7500
        self.ALL_MESSAGES = list()

# ANSI escape codes for text colors
RED = '\033[31m'
GREEN = '\033[32m'
YELLOW = '\033[33m'
BLUE = '\033[34m'
MAGENTA = '\033[35m'
CYAN = '\033[36m'
RESET = '\033[0m'

app_state = AppState()

# %%
def main():
    # instantiate chatbot
    openai.api_key = read_file_content('key_openai.txt').strip()

    # parse arguments
    parser = argparse.ArgumentParser(description="Chatbot using OpenAI API")
    parser.add_argument("--model", default=app_state.MODEL_NAME,
                        help="Model name (default: %(default)s)")
    parser.add_argument("--temperature", type=float, default=app_state.MODEL_TEMPERATURE,
                        help="Temperature (default: %(default)s)")
    args, unknown = parser.parse_known_args()

    app_state.MODEL_NAME = args.model
    app_state.MODEL_TEMPERATURE = args.temperature

    print(f"Current settings:\n"
        f"Model: {app_state.MODEL_NAME}\n"
        f"Temperature: {app_state.MODEL_TEMPERATURE}")
    print("Sample app usage: python chat.py --model gpt-3.5-turbo --temperature 0.2")


    print(f"{MAGENTA}\n\n****** IMPORTANT ******\n"
        "Type 'SCRATCHPAD' or 'M' to enter multi-line input mode to update the scratchpad.\n"
        f"Type 'END' to save and exit.\n{RESET}")

    while True:
        text = get_user_input()
        if text is None:
            continue
        if text == '':
            # empty submission, probably on accident
            continue

        # continue with composing conversation and response
        app_state.ALL_MESSAGES.append({'role': 'user', 'content': text})
        system_message = read_file_content('system_message.txt').replace('<<CODE>>', read_file_content('scratchpad.md'))
        conversation = list()
        conversation += app_state.ALL_MESSAGES
        conversation.append({'role': 'system', 'content': system_message})

        # generate a response
        response, tokens, processing_time = perform_chatbot_conversation(conversation)

        if tokens > app_state.MODEL_MAX_TOKENS:
            app_state.ALL_MESSAGES.pop(0)

        app_state.ALL_MESSAGES.append({'role': 'assistant', 'content': response})
        print_chatbot_response(response, tokens, processing_time)

# %%
import nbformat
from nbformat.v4 import new_notebook, new_markdown_cell

# List of file paths to open
file_paths = [
    "./log/openai/20230705_231722_gpt-4_request.md",
    "./log/openai/20230705_231731_495_response.md",
    "./log/openai/20230705_232912_gpt-4_request.md",
    "./log/openai/20230705_232922_651_response.md",
    "./log/openai/20230705_233120_gpt-4_request.md",
    "./log/openai/20230705_233129_768_response.md",
    "./log/openai/20230705_233723_gpt-4_request.md",
    "./log/openai/20230705_233807_870_response.md"
]

# Create a new notebook
nb = new_notebook()

# Add a new markdown cell for each file
for file_path in file_paths:
    with open(file_path, "r") as f:
        contents = f.read()
    cell = new_markdown_cell(contents)
    nb["cells"].append(cell)

# Save the notebook
nbformat.write(nb, "output.ipynb")

# %%
import nbformat
from nbformat.v4 import new_notebook, new_markdown_cell

# List of file paths to open
file_paths = [
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230627_121453_gpt-4_request.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230627_121524_1055_response.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230627_124944_gpt-3.5-turbo_request.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230627_124956_1003_response.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230628_104914_gpt-4_request.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230628_105003_2059_response.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230628_143217_gpt-4_request.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230628_143322_2082_response.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230628_184101_gpt-4_request.md",
    "/home/bitawatt/Project/3_Project/Apps/Coding_ChatBot_Assistant/log/openai/20230628_184204_3752_response.md"
]

# Create a new notebook
nb = new_notebook()

# Add a new markdown cell for each file
for file_path in file_paths:
    with open(file_path, "r") as f:
        contents = f.read()
    cell = new_markdown_cell(contents)
    nb["cells"].append(cell)

# Save the notebook
nbformat.write(nb, "/home/bitawatt/Project/2_Project/Notebook/Scrape.ipynb")
